# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

image_paths = [
    "/content/drive/MyDrive/OCR/Laver_Bazar/12.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/12.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/12.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/13.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/14.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/15.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/16.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/17.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/18.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/19.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/20.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/29.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/30.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/31.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/32.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/33.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/34.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/35.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/36.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/37.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/38.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/39.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/40.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/52.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/53.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/54.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/55.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/56.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/57.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/58.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/59.png",
    "/content/drive/MyDrive/OCR/Laver_Bazar/60.png"
    # add more paths here
]

prompt = "\nFree OCR."
output_path = "/content/output/dir"
os.makedirs(output_path, exist_ok=True)

for idx, image_file in enumerate(image_paths, start=1):
    print(f"\n========== Image {idx} ==========")
    print("Image path:", image_file)

    # Show image (optional)
    img = Image.open(image_file)
    plt.figure(figsize=(6, 6))
    plt.imshow(img)
    plt.axis("off")
    plt.show()

    # Run inference
    res = model.infer(
        tokenizer,
        prompt=prompt,
        image_file=image_file,
        output_path=output_path,
        image_size=640,
        base_size=1024,
        crop_mode=True,
        save_results=True,
        test_compress=False
    )

    # Print OCR result
    print("OCR Result:")
    print(res)
# Out:
# ========== Image 1 ==========
# Image path: /content/drive/MyDrive/OCR/Laver_Bazar/12.png
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([2, 100, 1280])
# ...
# পণ্য পরিমাণ খুচরা মূল্য সর্বমোট
# ক্লোজআপ ১p ১০০
# ক্লোজআপ ১p ১৪০
# রিন ১p ১৯০
# রিন ১p ৪০
# হুইল ১p ৩০
# হুইল ১p ১৪৫
# লাক্স ১p ৮০
# লাক্স ১p ৬০
# লাইফবয় ১p ১৯৫
# লাইফবয় ১p ৯০
# বিক্রেতার স্বাক্ষর
# মোট
# ===============save results:===============
# image: 0it [00:00, ?it/s]
# other: 0it [00:00, ?it/s]
# OCR Result:
# None
#
# ========== Image 2 ==========
# Image path: /content/drive/MyDrive/OCR/Laver_Bazar/12.png
# ...
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([2, 100, 1280])
# ...
# পণ্য পরিমাণ খুচরা মূল্য সর্বমোট
# ক্লোজআপ ১p ১০০
# ক্লোজআপ ১p ১৪০
# রিন ১p ১৯০
# রিন ১p ৪০
# ...
